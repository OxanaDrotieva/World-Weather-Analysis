# %%
# Import the dependencies
import pandas as pd
import numpy as np
import requests
from citipy import citipy
import time

# Import the API key
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 769

# %%
# starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning of the logging")
print("------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i%50 == 0 and i>=50):
        set_count += 1 
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON file and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_weather_description})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning of the logging
# ------------------------
# Processing Record 1 of Set 1 | marzuq
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | roma
# Processing Record 5 of Set 1 | nioro
# Processing Record 6 of Set 1 | mogadishu
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | araouane
# Processing Record 9 of Set 1 | cherskiy
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | makakilo city
# Processing Record 12 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | ilulissat
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | kulhudhuffushi
# Processing Record 21 of Set 1 | goias
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | vila franca do campo
# Processing Record 25 of Set 1 | levokumskoye
# Processing Record 26 of Set 1 | zhoucheng
# Processing Record 27 of Set 1 | general roca
# Processing Record 28 of Set 1 | plettenberg bay
# Processing Record 29 of Set 1 | brae
# Processing Record 30 of Set 1 | beloha
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | jorpeland
# Processing Record 33 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | zhigansk
# Processing Record 36 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | klaksvik
# Processing Record 39 of Set 1 | upernavik
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | wattegama
# Processing Record 45 of Set 1 | emba
# Processing Record 46 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | kosa
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | kortkeros
# Processing Record 1 of Set 2 | chinsali
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | oyama
# Processing Record 5 of Set 2 | iracoubo
# Processing Record 6 of Set 2 | bonga
# Processing Record 7 of Set 2 | the valley
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | kermanshah
# Processing Record 10 of Set 2 | tiksi
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | ternate
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | longyearbyen
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | rikitea
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | mahebourg
# Processing Record 21 of Set 2 | bambous virieux
# Processing Record 22 of Set 2 | chokurdakh
# Processing Record 23 of Set 2 | katsuura
# Processing Record 24 of Set 2 | palmer
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | catalina
# Processing Record 27 of Set 2 | darhan
# Processing Record 28 of Set 2 | intipuca
# Processing Record 29 of Set 2 | port hedland
# Processing Record 30 of Set 2 | codrington
# Processing Record 31 of Set 2 | husavik
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | viedma
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | watertown
# Processing Record 37 of Set 2 | lompoc
# Processing Record 38 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 2 | hervey bay
# Processing Record 40 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 2 | lorengau
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | faanui
# Processing Record 45 of Set 2 | sept-iles
# Processing Record 46 of Set 2 | puerto baquerizo moreno
# Processing Record 47 of Set 2 | flinders
# Processing Record 48 of Set 2 | beringovskiy
# Processing Record 49 of Set 2 | antalaha
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | ancud
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | kralendijk
# Processing Record 4 of Set 3 | saskylakh
# Processing Record 5 of Set 3 | tasiilaq
# Processing Record 6 of Set 3 | laguna
# Processing Record 7 of Set 3 | baymak
# Processing Record 8 of Set 3 | carnarvon
# Processing Record 9 of Set 3 | cockburn town
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | faya
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | uarini
# Processing Record 14 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 15 of Set 3 | antigonish
# Processing Record 16 of Set 3 | pevek
# Processing Record 17 of Set 3 | vaini
# Processing Record 18 of Set 3 | thompson
# Processing Record 19 of Set 3 | acapulco
# Processing Record 20 of Set 3 | indapur
# Processing Record 21 of Set 3 | hammerfest
# Processing Record 22 of Set 3 | waddan
# Processing Record 23 of Set 3 | izhma
# Processing Record 24 of Set 3 | kwidzyn
# Processing Record 25 of Set 3 | mingyue
# Processing Record 26 of Set 3 | fairbanks
# Processing Record 27 of Set 3 | port alfred
# Processing Record 28 of Set 3 | selfoss
# Processing Record 29 of Set 3 | santa ines
# Processing Record 30 of Set 3 | bredasdorp
# Processing Record 31 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 3 | esperance
# Processing Record 33 of Set 3 | lavrentiya
# Processing Record 34 of Set 3 | korla
# Processing Record 35 of Set 3 | qaqortoq
# Processing Record 36 of Set 3 | rocha
# Processing Record 37 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 3 | sayanskiy
# City not found. Skipping...
# Processing Record 39 of Set 3 | kimbe
# Processing Record 40 of Set 3 | san cristobal
# Processing Record 41 of Set 3 | ciudad bolivar
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | usinsk
# Processing Record 44 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 3 | ketchikan
# Processing Record 46 of Set 3 | baijiantan
# Processing Record 47 of Set 3 | westport
# Processing Record 48 of Set 3 | necochea
# Processing Record 49 of Set 3 | saint-philippe
# Processing Record 50 of Set 3 | cabo san lucas
# Processing Record 1 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 2 of Set 4 | yuzhno-sukhokumsk
# Processing Record 3 of Set 4 | serebryansk
# Processing Record 4 of Set 4 | coquimbo
# Processing Record 5 of Set 4 | touros
# Processing Record 6 of Set 4 | newport
# Processing Record 7 of Set 4 | mamallapuram
# Processing Record 8 of Set 4 | akcaabat
# Processing Record 9 of Set 4 | shakiso
# Processing Record 10 of Set 4 | asau
# Processing Record 11 of Set 4 | aksu
# Processing Record 12 of Set 4 | nome
# Processing Record 13 of Set 4 | ponta do sol
# Processing Record 14 of Set 4 | hurghada
# Processing Record 15 of Set 4 | taksimo
# Processing Record 16 of Set 4 | monrovia
# Processing Record 17 of Set 4 | victoria
# Processing Record 18 of Set 4 | nemuro
# Processing Record 19 of Set 4 | sorsk
# Processing Record 20 of Set 4 | ostrovnoy
# Processing Record 21 of Set 4 | nikolskoye
# Processing Record 22 of Set 4 | hambantota
# Processing Record 23 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 4 | tura
# Processing Record 25 of Set 4 | corinto
# Processing Record 26 of Set 4 | port lincoln
# Processing Record 27 of Set 4 | pacific grove
# Processing Record 28 of Set 4 | mehamn
# Processing Record 29 of Set 4 | grand-santi
# Processing Record 30 of Set 4 | russell
# Processing Record 31 of Set 4 | constitucion
# Processing Record 32 of Set 4 | borogontsy
# Processing Record 33 of Set 4 | karasburg
# Processing Record 34 of Set 4 | komsomolskiy
# Processing Record 35 of Set 4 | rafaela
# Processing Record 36 of Set 4 | hereford
# Processing Record 37 of Set 4 | zapadnaya dvina
# Processing Record 38 of Set 4 | dukat
# Processing Record 39 of Set 4 | okhotsk
# Processing Record 40 of Set 4 | tessalit
# Processing Record 41 of Set 4 | san patricio
# Processing Record 42 of Set 4 | santona
# Processing Record 43 of Set 4 | dieppe
# Processing Record 44 of Set 4 | vostochnyy
# Processing Record 45 of Set 4 | iquique
# Processing Record 46 of Set 4 | barrow
# Processing Record 47 of Set 4 | lalomanu
# City not found. Skipping...
# Processing Record 48 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 49 of Set 4 | talnakh
# Processing Record 50 of Set 4 | poum
# Processing Record 1 of Set 5 | bethel
# Processing Record 2 of Set 5 | moron de la frontera
# Processing Record 3 of Set 5 | grand gaube
# Processing Record 4 of Set 5 | koshurnikovo
# Processing Record 5 of Set 5 | aden
# Processing Record 6 of Set 5 | grindavik
# Processing Record 7 of Set 5 | bengkulu
# Processing Record 8 of Set 5 | airai
# Processing Record 9 of Set 5 | kahului
# Processing Record 10 of Set 5 | maxixe
# Processing Record 11 of Set 5 | yurty
# Processing Record 12 of Set 5 | davila
# Processing Record 13 of Set 5 | tamandare
# Processing Record 14 of Set 5 | castro
# Processing Record 15 of Set 5 | niteroi
# Processing Record 16 of Set 5 | paita
# Processing Record 17 of Set 5 | syamzha
# Processing Record 18 of Set 5 | luba
# Processing Record 19 of Set 5 | meulaboh
# Processing Record 20 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 21 of Set 5 | yulara
# Processing Record 22 of Set 5 | zonguldak
# Processing Record 23 of Set 5 | soanierana ivongo
# Processing Record 24 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 5 | vanimo
# Processing Record 26 of Set 5 | basco
# Processing Record 27 of Set 5 | avesta
# Processing Record 28 of Set 5 | canala
# Processing Record 29 of Set 5 | santa cruz
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | sao filipe
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | lagoa
# Processing Record 34 of Set 5 | charters towers
# Processing Record 35 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 5 | chengde
# Processing Record 37 of Set 5 | suluq
# Processing Record 38 of Set 5 | hobyo
# Processing Record 39 of Set 5 | ambon
# Processing Record 40 of Set 5 | novo aripuana
# Processing Record 41 of Set 5 | saint-michel-des-saints
# Processing Record 42 of Set 5 | manta
# Processing Record 43 of Set 5 | karratha
# Processing Record 44 of Set 5 | anadyr
# Processing Record 45 of Set 5 | vila velha
# Processing Record 46 of Set 5 | buala
# Processing Record 47 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 5 | arlit
# Processing Record 49 of Set 5 | puerto princesa
# Processing Record 50 of Set 5 | taoudenni
# Processing Record 1 of Set 6 | souillac
# Processing Record 2 of Set 6 | oudtshoorn
# Processing Record 3 of Set 6 | terney
# Processing Record 4 of Set 6 | chapais
# Processing Record 5 of Set 6 | pimentel
# Processing Record 6 of Set 6 | cidreira
# Processing Record 7 of Set 6 | kamenka
# Processing Record 8 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 6 | waipawa
# Processing Record 10 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 6 | poronaysk
# Processing Record 12 of Set 6 | trinidad
# Processing Record 13 of Set 6 | pisco
# Processing Record 14 of Set 6 | nichlaul
# Processing Record 15 of Set 6 | muros
# Processing Record 16 of Set 6 | svetlaya
# Processing Record 17 of Set 6 | quthing
# Processing Record 18 of Set 6 | kragero
# Processing Record 19 of Set 6 | kiparissia
# City not found. Skipping...
# Processing Record 20 of Set 6 | caravelas
# Processing Record 21 of Set 6 | thinadhoo
# Processing Record 22 of Set 6 | shenyang
# Processing Record 23 of Set 6 | suhbaatar
# Processing Record 24 of Set 6 | pakokku
# Processing Record 25 of Set 6 | katobu
# Processing Record 26 of Set 6 | doha
# Processing Record 27 of Set 6 | rajauri
# Processing Record 28 of Set 6 | romny
# Processing Record 29 of Set 6 | hasaki
# Processing Record 30 of Set 6 | san-pedro
# Processing Record 31 of Set 6 | filingue
# Processing Record 32 of Set 6 | guerrero negro
# Processing Record 33 of Set 6 | saraza
# Processing Record 34 of Set 6 | dubbo
# Processing Record 35 of Set 6 | matay
# Processing Record 36 of Set 6 | khorramshahr
# Processing Record 37 of Set 6 | imamoglu
# Processing Record 38 of Set 6 | namibe
# Processing Record 39 of Set 6 | mareeba
# Processing Record 40 of Set 6 | burla
# Processing Record 41 of Set 6 | nuuk
# Processing Record 42 of Set 6 | fortuna
# Processing Record 43 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 44 of Set 6 | kautokeino
# Processing Record 45 of Set 6 | cabra
# Processing Record 46 of Set 6 | keningau
# Processing Record 47 of Set 6 | weiser
# Processing Record 48 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 6 | gorele
# Processing Record 50 of Set 6 | lakatoro
# Processing Record 1 of Set 7 | haines junction
# Processing Record 2 of Set 7 | bud
# Processing Record 3 of Set 7 | lhokseumawe
# Processing Record 4 of Set 7 | labuhan
# Processing Record 5 of Set 7 | aldan
# Processing Record 6 of Set 7 | rotnes
# Processing Record 7 of Set 7 | berea
# Processing Record 8 of Set 7 | amaraji
# Processing Record 9 of Set 7 | tabou
# Processing Record 10 of Set 7 | quatre cocos
# Processing Record 11 of Set 7 | dera bugti
# Processing Record 12 of Set 7 | dingle
# Processing Record 13 of Set 7 | bunia
# Processing Record 14 of Set 7 | ukiah
# Processing Record 15 of Set 7 | saint-denis
# Processing Record 16 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 7 | jumla
# Processing Record 18 of Set 7 | limbang
# Processing Record 19 of Set 7 | bilma
# Processing Record 20 of Set 7 | egvekinot
# Processing Record 21 of Set 7 | sitka
# Processing Record 22 of Set 7 | union
# Processing Record 23 of Set 7 | ahipara
# Processing Record 24 of Set 7 | bartica
# Processing Record 25 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 26 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 7 | chuy
# Processing Record 28 of Set 7 | hailar
# Processing Record 29 of Set 7 | rancho mirage
# Processing Record 30 of Set 7 | lardos
# Processing Record 31 of Set 7 | ilhabela
# Processing Record 32 of Set 7 | nova borova
# Processing Record 33 of Set 7 | nishihara
# Processing Record 34 of Set 7 | kropotkin
# Processing Record 35 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 7 | agirish
# Processing Record 37 of Set 7 | dongsheng
# Processing Record 38 of Set 7 | taiyuan
# Processing Record 39 of Set 7 | masuda
# Processing Record 40 of Set 7 | daru
# Processing Record 41 of Set 7 | nelson bay
# Processing Record 42 of Set 7 | sterling
# Processing Record 43 of Set 7 | los llanos de aridane
# Processing Record 44 of Set 7 | ust-omchug
# Processing Record 45 of Set 7 | inirida
# Processing Record 46 of Set 7 | clonakilty
# Processing Record 47 of Set 7 | kollo
# Processing Record 48 of Set 7 | montemor-o-novo
# Processing Record 49 of Set 7 | bairiki
# Processing Record 50 of Set 7 | vardo
# Processing Record 1 of Set 8 | biak
# Processing Record 2 of Set 8 | batagay-alyta
# Processing Record 3 of Set 8 | provideniya
# Processing Record 4 of Set 8 | chuguyevka
# Processing Record 5 of Set 8 | popondetta
# Processing Record 6 of Set 8 | sindor
# Processing Record 7 of Set 8 | portland
# Processing Record 8 of Set 8 | krasnoarmeyskiy
# Processing Record 9 of Set 8 | ingolstadt
# Processing Record 10 of Set 8 | lalupon
# Processing Record 11 of Set 8 | hirara
# Processing Record 12 of Set 8 | sinnamary
# Processing Record 13 of Set 8 | yakeshi
# Processing Record 14 of Set 8 | shubarkuduk
# Processing Record 15 of Set 8 | sechura
# Processing Record 16 of Set 8 | batemans bay
# Processing Record 17 of Set 8 | hearst
# Processing Record 18 of Set 8 | broome
# Processing Record 19 of Set 8 | zaysan
# Processing Record 20 of Set 8 | scarborough
# Processing Record 21 of Set 8 | frankfort
# Processing Record 22 of Set 8 | oksfjord
# Processing Record 23 of Set 8 | iseyin
# Processing Record 24 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 25 of Set 8 | djougou
# Processing Record 26 of Set 8 | north platte
# Processing Record 27 of Set 8 | bozeman
# Processing Record 28 of Set 8 | yumen
# Processing Record 29 of Set 8 | coutances
# Processing Record 30 of Set 8 | veraval
# Processing Record 31 of Set 8 | bilibino
# Processing Record 32 of Set 8 | yanam
# Processing Record 33 of Set 8 | jiblah
# Processing Record 34 of Set 8 | la rioja
# Processing Record 35 of Set 8 | saint-francois
# Processing Record 36 of Set 8 | ola
# Processing Record 37 of Set 8 | amazar
# Processing Record 38 of Set 8 | kavieng
# Processing Record 39 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 8 | solginskiy
# Processing Record 41 of Set 8 | huarmey
# Processing Record 42 of Set 8 | kushmurun
# Processing Record 43 of Set 8 | am timan
# Processing Record 44 of Set 8 | elizabeth city
# Processing Record 45 of Set 8 | lazaro cardenas
# Processing Record 46 of Set 8 | kilindoni
# Processing Record 47 of Set 8 | sulangan
# Processing Record 48 of Set 8 | opuwo
# Processing Record 49 of Set 8 | carutapera
# Processing Record 50 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 9 | garden city
# Processing Record 3 of Set 9 | hualmay
# Processing Record 4 of Set 9 | sioux lookout
# Processing Record 5 of Set 9 | manyana
# Processing Record 6 of Set 9 | achisay
# City not found. Skipping...
# Processing Record 7 of Set 9 | kholm
# Processing Record 8 of Set 9 | danshui
# Processing Record 9 of Set 9 | huambo
# Processing Record 10 of Set 9 | predivinsk
# Processing Record 11 of Set 9 | neiafu
# Processing Record 12 of Set 9 | donna
# Processing Record 13 of Set 9 | lesnoy
# Processing Record 14 of Set 9 | verkh-usugli
# Processing Record 15 of Set 9 | aykhal
# Processing Record 16 of Set 9 | mnogovershinnyy
# Processing Record 17 of Set 9 | mantua
# Processing Record 18 of Set 9 | puro
# Processing Record 19 of Set 9 | padilla
# Processing Record 20 of Set 9 | kaeo
# Processing Record 21 of Set 9 | kavaratti
# Processing Record 22 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 23 of Set 9 | porteirinha
# Processing Record 24 of Set 9 | wolsztyn
# Processing Record 25 of Set 9 | koutsouras
# Processing Record 26 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 9 | seydi
# Processing Record 29 of Set 9 | aklavik
# Processing Record 30 of Set 9 | kjollefjord
# Processing Record 31 of Set 9 | ilam
# Processing Record 32 of Set 9 | sungaipenuh
# Processing Record 33 of Set 9 | lucero
# Processing Record 34 of Set 9 | snezhnogorsk
# Processing Record 35 of Set 9 | naze
# Processing Record 36 of Set 9 | victor harbor
# Processing Record 37 of Set 9 | champerico
# Processing Record 38 of Set 9 | naples
# Processing Record 39 of Set 9 | san vicente
# Processing Record 40 of Set 9 | bandundu
# Processing Record 41 of Set 9 | beyneu
# Processing Record 42 of Set 9 | micheweni
# Processing Record 43 of Set 9 | san miguel
# Processing Record 44 of Set 9 | barinas
# Processing Record 45 of Set 9 | mackenzie
# Processing Record 46 of Set 9 | fort nelson
# Processing Record 47 of Set 9 | birjand
# Processing Record 48 of Set 9 | impfondo
# Processing Record 49 of Set 9 | avera
# Processing Record 50 of Set 9 | sorland
# Processing Record 1 of Set 10 | billings
# Processing Record 2 of Set 10 | parras
# City not found. Skipping...
# Processing Record 3 of Set 10 | porangatu
# Processing Record 4 of Set 10 | magdagachi
# Processing Record 5 of Set 10 | geraldton
# Processing Record 6 of Set 10 | najran
# Processing Record 7 of Set 10 | zheleznodorozhnyy
# Processing Record 8 of Set 10 | karrapur
# Processing Record 9 of Set 10 | berlevag
# Processing Record 10 of Set 10 | san ramon
# Processing Record 11 of Set 10 | trelew
# Processing Record 12 of Set 10 | soyo
# Processing Record 13 of Set 10 | paamiut
# Processing Record 14 of Set 10 | moron
# Processing Record 15 of Set 10 | gardan diwal
# City not found. Skipping...
# Processing Record 16 of Set 10 | yukhnov
# Processing Record 17 of Set 10 | kingman
# Processing Record 18 of Set 10 | karur
# Processing Record 19 of Set 10 | sumbe
# Processing Record 20 of Set 10 | haapiti
# Processing Record 21 of Set 10 | port macquarie
# Processing Record 22 of Set 10 | lexington park
# Processing Record 23 of Set 10 | khash
# Processing Record 24 of Set 10 | vestmannaeyjar
# Processing Record 25 of Set 10 | maceio
# Processing Record 26 of Set 10 | svarstad
# Processing Record 27 of Set 10 | lyuban
# Processing Record 28 of Set 10 | kleck
# City not found. Skipping...
# Processing Record 29 of Set 10 | sao jose da coroa grande
# Processing Record 30 of Set 10 | puerto del rosario
# Processing Record 31 of Set 10 | petrovsk
# Processing Record 32 of Set 10 | greenwood
# Processing Record 33 of Set 10 | ginda
# Processing Record 34 of Set 10 | praia da vitoria
# Processing Record 35 of Set 10 | narsaq
# Processing Record 36 of Set 10 | payo
# Processing Record 37 of Set 10 | vao
# Processing Record 38 of Set 10 | dhidhdhoo
# Processing Record 39 of Set 10 | armizonskoye
# Processing Record 40 of Set 10 | thunder bay
# Processing Record 41 of Set 10 | ryotsu
# Processing Record 42 of Set 10 | lasa
# Processing Record 43 of Set 10 | whitehorse
# Processing Record 44 of Set 10 | cocobeach
# Processing Record 45 of Set 10 | lahij
# Processing Record 46 of Set 10 | tupik
# Processing Record 47 of Set 10 | kutum
# Processing Record 48 of Set 10 | inhambane
# Processing Record 49 of Set 10 | springbok
# Processing Record 50 of Set 10 | yerbogachen
# Processing Record 1 of Set 11 | west bay
# Processing Record 2 of Set 11 | kasongo-lunda
# Processing Record 3 of Set 11 | iquitos
# Processing Record 4 of Set 11 | uyuni
# Processing Record 5 of Set 11 | lukulu
# Processing Record 6 of Set 11 | marawi
# Processing Record 7 of Set 11 | tromso
# Processing Record 8 of Set 11 | stamsund
# City not found. Skipping...
# Processing Record 9 of Set 11 | ouango
# Processing Record 10 of Set 11 | mitzic
# Processing Record 11 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 12 of Set 11 | ust-tsilma
# Processing Record 13 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 11 | sola
# Processing Record 15 of Set 11 | purranque
# Processing Record 16 of Set 11 | sao felix do xingu
# Processing Record 17 of Set 11 | iqaluit
# Processing Record 18 of Set 11 | ibotirama
# Processing Record 19 of Set 11 | lagos
# Processing Record 20 of Set 11 | lekoni
# Processing Record 21 of Set 11 | tomari
# Processing Record 22 of Set 11 | nasirabad
# Processing Record 23 of Set 11 | narasannapeta
# Processing Record 24 of Set 11 | kodinsk
# Processing Record 25 of Set 11 | vagur
# Processing Record 26 of Set 11 | les escoumins
# Processing Record 27 of Set 11 | dunedin
# Processing Record 28 of Set 11 | awjilah
# Processing Record 29 of Set 11 | bubaque
# Processing Record 30 of Set 11 | port-gentil
# Processing Record 31 of Set 11 | san jeronimo
# Processing Record 32 of Set 11 | athabasca
# Processing Record 33 of Set 11 | aksha
# Processing Record 34 of Set 11 | kirakira
# Processing Record 35 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 11 | galesong
# Processing Record 37 of Set 11 | xuddur
# Processing Record 38 of Set 11 | farafangana
# Processing Record 39 of Set 11 | qasigiannguit
# Processing Record 40 of Set 11 | san luis
# Processing Record 41 of Set 11 | key west
# Processing Record 42 of Set 11 | huangnihe
# Processing Record 43 of Set 11 | san quintin
# Processing Record 44 of Set 11 | grimshaw
# Processing Record 45 of Set 11 | nuevo ideal
# Processing Record 46 of Set 11 | tall kayf
# Processing Record 47 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 11 | cuenca
# Processing Record 49 of Set 11 | san fernando
# Processing Record 50 of Set 11 | olafsvik
# Processing Record 1 of Set 12 | aketi
# Processing Record 2 of Set 12 | santa rita
# Processing Record 3 of Set 12 | kedrovyy
# Processing Record 4 of Set 12 | progreso
# Processing Record 5 of Set 12 | port blair
# Processing Record 6 of Set 12 | jasper
# Processing Record 7 of Set 12 | kruisfontein
# Processing Record 8 of Set 12 | kutahya
# Processing Record 9 of Set 12 | amahai
# Processing Record 10 of Set 12 | stony plain
# Processing Record 11 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 12 | apac
# Processing Record 13 of Set 12 | rassvet
# Processing Record 14 of Set 12 | rawson
# Processing Record 15 of Set 12 | yishui
# Processing Record 16 of Set 12 | tallahassee
# Processing Record 17 of Set 12 | tahta
# Processing Record 18 of Set 12 | kununurra
# Processing Record 19 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 12 | feijo
# Processing Record 21 of Set 12 | nanortalik
# Processing Record 22 of Set 12 | tuatapere
# Processing Record 23 of Set 12 | suntar
# Processing Record 24 of Set 12 | kommunisticheskiy
# Processing Record 25 of Set 12 | clarksville
# Processing Record 26 of Set 12 | kitimat
# Processing Record 27 of Set 12 | mesyagutovo
# Processing Record 28 of Set 12 | porbandar
# Processing Record 29 of Set 12 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 30 of Set 12 | luderitz
# Processing Record 31 of Set 12 | dwarka
# Processing Record 32 of Set 12 | nyurba
# Processing Record 33 of Set 12 | dublin
# Processing Record 34 of Set 12 | udachnyy
# Processing Record 35 of Set 12 | timbiqui
# Processing Record 36 of Set 12 | teguldet
# Processing Record 37 of Set 12 | quelimane
# Processing Record 38 of Set 12 | chumikan
# Processing Record 39 of Set 12 | yomou
# Processing Record 40 of Set 12 | khandbari
# Processing Record 41 of Set 12 | jacareacanga
# Processing Record 42 of Set 12 | miandrivazo
# Processing Record 43 of Set 12 | metsovon
# City not found. Skipping...
# Processing Record 44 of Set 12 | abha
# Processing Record 45 of Set 12 | cayenne
# Processing Record 46 of Set 12 | craig
# Processing Record 47 of Set 12 | vostok
# Processing Record 48 of Set 12 | saldanha
# Processing Record 49 of Set 12 | leningradskiy
# Processing Record 50 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 1 of Set 13 | juba
# Processing Record 2 of Set 13 | waingapu
# Processing Record 3 of Set 13 | cutzamala
# City not found. Skipping...
# Processing Record 4 of Set 13 | trujillo
# Processing Record 5 of Set 13 | rabo de peixe
# Processing Record 6 of Set 13 | lincoln
# Processing Record 7 of Set 13 | gamba
# Processing Record 8 of Set 13 | gat
# Processing Record 9 of Set 13 | morondava
# Processing Record 10 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 13 | dawlatabad
# Processing Record 12 of Set 13 | evensk
# Processing Record 13 of Set 13 | porto novo
# Processing Record 14 of Set 13 | adre
# Processing Record 15 of Set 13 | rincon
# Processing Record 16 of Set 13 | yellandu
# Processing Record 17 of Set 13 | pali
# Processing Record 18 of Set 13 | golden
# Processing Record 19 of Set 13 | muisne
# Processing Record 20 of Set 13 | great yarmouth
# Processing Record 21 of Set 13 | krasnoyarskiy
# Processing Record 22 of Set 13 | itaituba
# Processing Record 23 of Set 13 | aswan
# Processing Record 24 of Set 13 | jatai
# Processing Record 25 of Set 13 | nador
# Processing Record 26 of Set 13 | kalga
# Processing Record 27 of Set 13 | zistersdorf
# Processing Record 28 of Set 13 | coos bay
# Processing Record 29 of Set 13 | mutoko
# Processing Record 30 of Set 13 | paicandu
# Processing Record 31 of Set 13 | saint-augustin
# Processing Record 32 of Set 13 | samarai
# Processing Record 33 of Set 13 | sidi ali
# Processing Record 34 of Set 13 | northam
# Processing Record 35 of Set 13 | badgam
# City not found. Skipping...
# Processing Record 36 of Set 13 | saint-louis
# Processing Record 37 of Set 13 | innisfail
# Processing Record 38 of Set 13 | hamilton
# Processing Record 39 of Set 13 | skjervoy
# Processing Record 40 of Set 13 | kushiro
# Processing Record 41 of Set 13 | belaya gora
# Processing Record 42 of Set 13 | natal
# Processing Record 43 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 13 | kabompo
# Processing Record 45 of Set 13 | candawaga
# City not found. Skipping...
# Processing Record 46 of Set 13 | nhulunbuy
# Processing Record 47 of Set 13 | boysun
# Processing Record 48 of Set 13 | saint simons
# Processing Record 49 of Set 13 | san martin
# Processing Record 50 of Set 13 | chilca
# Processing Record 1 of Set 14 | myitkyina
# Processing Record 2 of Set 14 | challans
# Processing Record 3 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 14 | bogdanovich
# Processing Record 5 of Set 14 | strezhevoy
# Processing Record 6 of Set 14 | kousseri
# Processing Record 7 of Set 14 | abu zabad
# Processing Record 8 of Set 14 | vicuna
# Processing Record 9 of Set 14 | la orilla
# Processing Record 10 of Set 14 | rambha
# Processing Record 11 of Set 14 | peniche
# Processing Record 12 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 13 of Set 14 | taneatua
# City not found. Skipping...
# Processing Record 14 of Set 14 | luau
# Processing Record 15 of Set 14 | nuristan
# Processing Record 16 of Set 14 | saint-pierre
# Processing Record 17 of Set 14 | manggar
# Processing Record 18 of Set 14 | gonbad-e qabus
# Processing Record 19 of Set 14 | mizunami
# Processing Record 20 of Set 14 | san rafael
# Processing Record 21 of Set 14 | sassandra
# Processing Record 22 of Set 14 | camacha
# Processing Record 23 of Set 14 | marathon
# Processing Record 24 of Set 14 | kasempa
# Processing Record 25 of Set 14 | moree
# Processing Record 26 of Set 14 | emborion
# Processing Record 27 of Set 14 | norden
# Processing Record 28 of Set 14 | serenje
# Processing Record 29 of Set 14 | tomatlan
# Processing Record 30 of Set 14 | caramay
# Processing Record 31 of Set 14 | masterton
# Processing Record 32 of Set 14 | te anau
# Processing Record 33 of Set 14 | muroto
# Processing Record 34 of Set 14 | auki
# Processing Record 35 of Set 14 | sale
# Processing Record 36 of Set 14 | barra do garcas
# Processing Record 37 of Set 14 | ponta delgada
# Processing Record 38 of Set 14 | maarianhamina
# Processing Record 39 of Set 14 | la ronge
# Processing Record 40 of Set 14 | bandiagara
# Processing Record 41 of Set 14 | ankpa
# Processing Record 42 of Set 14 | kargat
# Processing Record 43 of Set 14 | ravar
# Processing Record 44 of Set 14 | duz
# City not found. Skipping...
# Processing Record 45 of Set 14 | san jose
# Processing Record 46 of Set 14 | niksic
# Processing Record 47 of Set 14 | lillooet
# Processing Record 48 of Set 14 | lukaya
# Processing Record 49 of Set 14 | mount isa
# Processing Record 50 of Set 14 | whitianga
# Processing Record 1 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 15 | sao gabriel da cachoeira
# Processing Record 3 of Set 15 | pasni
# Processing Record 4 of Set 15 | khorixas
# Processing Record 5 of Set 15 | half moon bay
# Processing Record 6 of Set 15 | ostersund
# Processing Record 7 of Set 15 | igrim
# Processing Record 8 of Set 15 | dzilam gonzalez
# Processing Record 9 of Set 15 | havre-saint-pierre
# Processing Record 10 of Set 15 | pangkalanbuun
# Processing Record 11 of Set 15 | zarubino
# Processing Record 12 of Set 15 | eureka
# Processing Record 13 of Set 15 | silver city
# Processing Record 14 of Set 15 | yangjiang
# Processing Record 15 of Set 15 | orocue
# Processing Record 16 of Set 15 | dymer
# Processing Record 17 of Set 15 | kwekwe
# Processing Record 18 of Set 15 | kerema
# Processing Record 19 of Set 15 | wanaka
# Processing Record 20 of Set 15 | goderich
# Processing Record 21 of Set 15 | dinghai
# Processing Record 22 of Set 15 | hamada
# Processing Record 23 of Set 15 | roebourne
# Processing Record 24 of Set 15 | maragogi
# Processing Record 25 of Set 15 | zeya
# Processing Record 26 of Set 15 | andenes
# Processing Record 27 of Set 15 | palu
# Processing Record 28 of Set 15 | shkotovo-26
# City not found. Skipping...
# Processing Record 29 of Set 15 | manavalakurichi
# Processing Record 30 of Set 15 | vilyuysk
# Processing Record 31 of Set 15 | mayumba
# Processing Record 32 of Set 15 | iisalmi
# Processing Record 33 of Set 15 | pauini
# Processing Record 34 of Set 15 | vila do maio
# Processing Record 35 of Set 15 | kieta
# Processing Record 36 of Set 15 | buraydah
# Processing Record 37 of Set 15 | bourges
# Processing Record 38 of Set 15 | swan hill
# Processing Record 39 of Set 15 | okato
# Processing Record 40 of Set 15 | vyartsilya
# Processing Record 41 of Set 15 | kailua
# Processing Record 42 of Set 15 | koygorodok
# Processing Record 43 of Set 15 | bonthe
# Processing Record 44 of Set 15 | semey
# Processing Record 45 of Set 15 | teya
# Processing Record 46 of Set 15 | phangnga
# Processing Record 47 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 15 | uryupinsk
# Processing Record 49 of Set 15 | deputatskiy
# Processing Record 50 of Set 15 | kiama
# Processing Record 1 of Set 16 | satipo
# Processing Record 2 of Set 16 | mamontovo
# Processing Record 3 of Set 16 | montepuez
# Processing Record 4 of Set 16 | brandon
# Processing Record 5 of Set 16 | buchanan
# Processing Record 6 of Set 16 | berdigestyakh
# Processing Record 7 of Set 16 | kinlochleven
# Processing Record 8 of Set 16 | vitimskiy
# City not found. Skipping...
# Processing Record 9 of Set 16 | kvarkeno
# Processing Record 10 of Set 16 | maryville
# Processing Record 11 of Set 16 | noshiro
# Processing Record 12 of Set 16 | shieli
# Processing Record 13 of Set 16 | sisimiut
# Processing Record 14 of Set 16 | chisinau
# Processing Record 15 of Set 16 | ustka
# Processing Record 16 of Set 16 | coihueco
# Processing Record 17 of Set 16 | dixon
# Processing Record 18 of Set 16 | sao joao da barra
# Processing Record 19 of Set 16 | santa maria da vitoria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Marzuq  14.4000   46.4667     61.20        37           0
# 1  Punta Arenas -53.1500  -70.9167     51.12        50          72
# 2    Butaritari   3.0707  172.7902     82.09        73         100
# 3          Roma  43.2128  -75.4557     41.88        69          20
# 4         Nioro  13.3500  -15.7500     95.83        18          24
#
#    Wind Speed Country Current Description
# 0        3.91      YE           clear sky
# 1       26.22      CL       broken clouds
# 2       17.00      KI     overcast clouds
# 3        3.00      US          few clouds
# 4        3.60      GM          few clouds

# %%
city_data_df.dtypes
# Out:
# City                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Country                 object
# Current Description     object
# dtype: object

# %%
# Reorder the columns
city_data_df_new = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"] 
city_data_df = city_data_df[city_data_df_new]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Marzuq      YE  14.4000   46.4667     61.20        37           0
# 1  Punta Arenas      CL -53.1500  -70.9167     51.12        50          72
# 2    Butaritari      KI   3.0707  172.7902     82.09        73         100
# 3          Roma      US  43.2128  -75.4557     41.88        69          20
# 4         Nioro      GM  13.3500  -15.7500     95.83        18          24
# 5     Mogadishu      SO   2.0371   45.3438     79.83        82          69
# 6       Ushuaia      AR -54.8000  -68.3000     46.06        71          75
# 7      Araouane      ML  18.9048   -3.5265     80.29         7           9
# 8      Cherskiy      RU  68.7500  161.3000    -42.77       100          48
# 9     Jamestown      US  42.0970  -79.2353     39.52        69          20
#
#    Wind Speed      Current Description
# 0        3.91                clear sky
# 1       26.22            broken clouds
# 2       17.00          overcast clouds
# 3        3.00               few clouds
# 4        3.60               few clouds
# 5       21.00            broken clouds
# 6       34.52  light intensity drizzle
# 7        7.31                clear sky
# 8        2.24         scattered clouds
# 9       15.01               few clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the city_data_df into a CSV
city_data_df.to_csv(output_data_file, index_label="City ID")
